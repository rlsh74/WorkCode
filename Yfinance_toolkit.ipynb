# %% [markdown]
# ## yfinance toolkit

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
ticker = 'NEM'

# %%
dict = yf.Ticker(ticker).info
dict
# Out:
# {'zip': '80237',
#  'sector': 'Basic Materials',
#  'fullTimeEmployees': 14300,
#  'longBusinessSummary': 'Newmont Corporation engages in the production and exploration of gold. It also explores for copper, silver, zinc, and lead. The company has operations and/or assets in the United States, Canada, Mexico, Dominican Republic, Peru, Suriname, Argentina, Chile, Australia, and Ghana. As of December 31, 2020, it had proven and probable gold reserves of 94.2 million ounces and land position of 58,900 square kilometers. The company was founded in 1916 and is headquartered in Denver, Colorado.',
#  'city': 'Denver',
#  'phone': '303-863-7414',
#  'state': 'CO',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.newmont.com',
#  'maxAge': 1,
#  'address1': '6900 East Layton Avenue',
#  'fax': '303-837-5837',
#  'industry': 'Gold',
#  'address2': 'Suite 700',
#  'previousClose': 62.8,
#  'regularMarketOpen': 62.8,
#  'twoHundredDayAverage': 60.87434,
# ...

# %%
dict['sector'], dict['industry'], dict['longName']
# Out:
# ('Basic Materials', 'Gold', 'Newmont Corporation')

# %%
dict['sector']
# Out:
# 'Basic Materials'

# %%
dict['sector']
# Out:
# 52110.733312

# %%
60.12/57.70-1
# Out:
# 0.04194107452339679

# %%
#Get dividents and stock splits (returned as df)
yf.Ticker(ticker).actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-02-17   0.066667           0.0
# 1987-05-14   0.080000           0.0
# 1987-06-11   0.000000           2.0
# 1987-08-20   0.080000           0.0
# 1987-09-25   0.032000           0.0
# ...               ...           ...
# 2020-03-04   0.140000           0.0
# 2020-06-03   0.250000           0.0
# 2020-09-09   0.250000           0.0
# 2020-12-10   0.400000           0.0
# 2021-03-03   0.550000           0.0
#
# [143 rows x 2 columns]

# %%
#Get the annual balance sheets for the past 4 years (df)
df = yf.Ticker(ticker).balance_sheet
df
# Out:
#                                     2020-12-31    2019-12-31    2018-12-31  \
# Capital Surplus                   1.810300e+10  1.821600e+10  9.618000e+09
# Total Liab                        1.749000e+10  1.755700e+10  9.203000e+09
# Total Stockholder Equity          2.300800e+10  2.142000e+10  1.050200e+10
# Minority Interest                 8.710000e+08  9.970000e+08  1.010000e+09
# Other Current Liab                1.358000e+09  9.660000e+08  2.620000e+08
# Total Assets                      4.136900e+10  3.997400e+10  2.071500e+10
# Common Stock                      1.287000e+09  1.298000e+09  8.550000e+08
# Other Current Assets              4.360000e+08  1.593000e+09  2.510000e+08
# Retained Earnings                 4.002000e+09  2.291000e+09  3.830000e+08
# Other Liab                        7.985000e+09  8.391000e+09  3.808000e+09
# Good Will                         2.771000e+09  2.674000e+09  5.800000e+07
# ...

# %%
df.iloc[df.index == 'Cash', 0][0]
# Out:
# 5540000000.0

# %%
# Get the nex earnings date, earnings and revenue expectations
yf.Ticker(ticker).calendar
# Out:
#                                 Value
# Earnings Date     2021-04-29 00:00:00
# Earnings Average                 0.85
# Earnings Low                     0.58
# Earnings High                     1.1
# Revenue Average            3328300000
# Revenue Low                3002000000
# Revenue High               3550890000

# %%
#Get the annual cashflow for the past 4 years (df)
df = yf.Ticker(ticker).cashflow
df
# Out:
#                                              2020-12-31    2019-12-31  \
# Investments                                2.680000e+08  5.900000e+07
# Change To Liabilities                     -5.000000e+07  1.440000e+08
# Total Cashflows From Investing Activities  9.100000e+07 -1.226000e+09
# Net Borrowings                            -2.410000e+08 -1.241000e+09
# Total Cash From Financing Activities      -1.680000e+09 -2.777000e+09
# Change To Operating Activities             4.550000e+08 -1.280000e+08
# Issuance Of Stock                          5.100000e+07  5.100000e+07
# Net Income                                 2.829000e+09  2.805000e+09
# Change In Cash                             3.299000e+09 -1.140000e+09
# Repurchase Of Stock                       -5.690000e+08 -5.290000e+08
# Effect Of Exchange Rate                    6.000000e+06 -3.000000e+06
# Total Cash From Operating Activities       4.882000e+09  2.866000e+09
# ...

# %%
df.iloc[df.index == 'Investments', 0][0]
# Out:
# 268000000.0

# %%
#Get dividends
yf.Ticker(ticker).dividends
# Out:
# Date
# 1987-02-17    0.066667
# 1987-05-14    0.080000
# 1987-08-20    0.080000
# 1987-09-25    0.032000
# 1987-11-19    0.120000
#                 ...
# 2020-03-04    0.140000
# 2020-06-03    0.250000
# 2020-09-09    0.250000
# 2020-12-10    0.400000
# 2021-03-03    0.550000
# Name: Dividends, Length: 140, dtype: float64

# %%
#Get the revenue and earnings for the past 4 years
yf.Ticker(ticker).earnings
# Out:
#           Revenue    Earnings
# Year
# 2017   7379000000  -114000000
# 2018   7253000000   341000000
# 2019   9740000000  2805000000
# 2020  11497000000  2829000000

# %%
yf.Ticker(ticker).financials
# Out:
#                                            2020-12-31    2019-12-31  \
# Research Development                      122000000.0   150000000.0
# Effect Of Accounting Charges                     None          None
# Income Before Tax                        3332000000.0  3788000000.0
# Minority Interest                         871000000.0   997000000.0
# Net Income                               2829000000.0  2805000000.0
# Selling General Administrative            361000000.0   293000000.0
# Gross Profit                             6159000000.0  4377000000.0
# Ebit                                     3299000000.0  1754000000.0
# Operating Income                         3299000000.0  1754000000.0
# Other Operating Expenses                         None          None
# Interest Expense                         -308000000.0  -301000000.0
# Extraordinary Items                              None          None
# Non Recurring                                    None          None
# ...

# %%
yf.Ticker(ticker).get_actions()
# Out:
#             Dividends  Stock Splits
# Date
# 1987-02-17   0.066667           0.0
# 1987-05-14   0.080000           0.0
# 1987-06-11   0.000000           2.0
# 1987-08-20   0.080000           0.0
# 1987-09-25   0.032000           0.0
# ...               ...           ...
# 2020-03-04   0.140000           0.0
# 2020-06-03   0.250000           0.0
# 2020-09-09   0.250000           0.0
# 2020-12-10   0.400000           0.0
# 2021-03-03   0.550000           0.0
#
# [143 rows x 2 columns]

# %%
yf.Ticker(ticker).get_balance_sheet()
# Out:
#                                     2020-12-31    2019-12-31    2018-12-31  \
# Capital Surplus                   1.810300e+10  1.821600e+10  9.618000e+09
# Total Liab                        1.749000e+10  1.755700e+10  9.203000e+09
# Total Stockholder Equity          2.300800e+10  2.142000e+10  1.050200e+10
# Minority Interest                 8.710000e+08  9.970000e+08  1.010000e+09
# Other Current Liab                1.358000e+09  9.660000e+08  2.620000e+08
# Total Assets                      4.136900e+10  3.997400e+10  2.071500e+10
# Common Stock                      1.287000e+09  1.298000e+09  8.550000e+08
# Other Current Assets              4.360000e+08  1.593000e+09  2.510000e+08
# Retained Earnings                 4.002000e+09  2.291000e+09  3.830000e+08
# Other Liab                        7.985000e+09  8.391000e+09  3.808000e+09
# Good Will                         2.771000e+09  2.674000e+09  5.800000e+07
# ...

# %%
yf.Ticker(ticker).get_institutional_holders()
# Out:
#                                    Holder    Shares Date Reported   % Out  \
# 0                          Blackrock Inc.  93621891    2020-12-30  0.1169
# 1              Vanguard Group, Inc. (The)  73357461    2020-12-30  0.0916
# 2          Van Eck Associates Corporation  38024490    2020-12-30  0.0475
# 3                State Street Corporation  36406930    2020-12-30  0.0454
# 4                                FMR, LLC  24384169    2020-12-30  0.0304
# 5        Deutsche Bank Aktiengesellschaft  19635415    2020-12-30  0.0245
# 6  First Eagle Investment Management, LLC  18366344    2020-12-30  0.0229
# 7                 Flossbach von Storch AG  14192359    2020-12-30  0.0177
# 8           Geode Capital Management, LLC  12748126    2020-12-30  0.0159
# 9              Northern Trust Corporation  11147154    2020-12-30  0.0139
#
#         Value
# 0  5607015051
# 1  4393378339
# 2  2277286706
# 3  2180411037
# 4  1460367881
# 5  1175965004
# 6  1099960342
# 7   849980380
# ...

# %%
yf.Ticker(ticker).get_isin()
# Out:
# 'US6516391066'

# %%
yf.Ticker(ticker).get_mutualfund_holders()
# Out:
#                                               Holder    Shares Date Reported  \
# 0              VanEck Vectors ETF Tr-Gold Miners ETF  33108031    2021-01-30
# 1             Vanguard Total Stock Market Index Fund  22647982    2020-12-30
# 2                            Vanguard 500 Index Fund  16097606    2020-12-30
# 3                        Vanguard Mid-Cap Index Fund   9083825    2020-12-30
# 4                             SPDR S&P 500 ETF Trust   8189900    2021-02-27
# 5                            First Eagle Global Fund   8146408    2021-01-30
# 6                            Fidelity 500 Index Fund   7275073    2021-02-27
# 7                iShares MSCI USA Min Vol Factor ETF   6907549    2021-02-27
# 8  Vanguard Institutional Index Fund-Institutiona...   6605619    2020-12-30
# 9                           iShares Core S&P 500 ETF   6204261    2021-02-27
#
#     % Out       Value
# 0  0.0413  1973238647
# 1  0.0283  1356387641
# 2  0.0201   964085623
# 3  0.0113   544030279
# ...

# %%
yf.Ticker(ticker).get_recommendations()
# Out:
#                               Firm      To Grade From Grade Action
# Date
# 2012-04-03 06:33:00      Citigroup       Neutral              down
# 2012-05-24 06:15:00      Jefferies          Hold              main
# 2012-07-09 05:58:00  Deutsche Bank          Hold              main
# 2012-07-16 06:46:00      Citigroup       Neutral              main
# 2012-07-27 09:18:00    BMO Capital    Outperform              main
# ...                            ...           ...        ...    ...
# 2020-05-07 15:06:33   B. Riley FBR           Buy              main
# 2020-05-19 11:32:37   B. Riley FBR           Buy              main
# 2020-06-17 11:53:08  Deutsche Bank           Buy              main
# 2020-07-20 11:48:05       Barclays  Equal-Weight              main
# 2020-08-24 14:29:34            UBS       Neutral              main
#
# [163 rows x 4 columns]

# %%
yf.Ticker(ticker).get_sustainability()
# Out:
#                                  Value
# 2021-3
# palmOil                          False
# controversialWeapons             False
# gambling                         False
# socialScore                      11.12
# nuclear                          False
# furLeather                       False
# alcoholic                        False
# gmo                              False
# catholic                         False
# socialPercentile                  None
# peerCount                           15
# governanceScore                   4.91
# environmentPercentile             None
# animalTesting                    False
# tobacco                          False
# totalEsg                         25.45
# highestControversy                   3
# esgPerformance                AVG_PERF
# coal                             False
# pesticides                       False
# adult                            False
# percentile                       40.61
# peerGroup              Precious Metals
# ...

# %%
yf.Ticker(ticker).history()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-03-08  56.860001  56.889999  55.630001  56.389999   7020200          0
# 2021-03-09  57.549999  58.119999  56.959999  57.250000   6590000          0
# 2021-03-10  57.970001  58.820000  57.279999  58.180000   7001600          0
# 2021-03-11  58.580002  58.650002  57.709999  58.450001   6391700          0
# 2021-03-12  57.470001  59.020000  57.349998  58.990002   5666600          0
# 2021-03-15  59.570000  61.950001  59.380001  61.419998  11254400          0
# 2021-03-16  61.369999  62.380001  60.939999  61.820000   8237600          0
# 2021-03-17  61.439999  63.320000  60.790001  62.970001   7752900          0
# 2021-03-18  62.139999  63.630001  62.049999  62.259998   8470500          0
# 2021-03-19  62.279999  62.509998  61.549999  61.930000  31243800          0
# 2021-03-22  61.220001  61.500000  60.369999  60.889999   6348000          0
# ...

# %%
yf.Ticker(ticker).option_chain()
# Out:
# Options(calls=        contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0   NEM210409C00050500 2021-03-04 16:18:10    50.5       6.40  10.85  11.65
# 1   NEM210409C00052000 2021-03-16 17:13:22    52.0      10.36   9.45  10.25
# 2   NEM210409C00052500 2021-04-01 16:19:34    52.5       8.75   9.05   9.50
# 3   NEM210409C00053000 2021-04-05 18:37:38    53.0       9.40   8.60   9.05
# 4   NEM210409C00054000 2021-03-25 15:03:54    54.0       5.40   7.60   8.05
# 5   NEM210409C00054500 2021-03-26 16:50:40    54.5       5.62   7.30   7.50
# 6   NEM210409C00055000 2021-04-06 19:37:52    55.0       7.96   6.90   7.00
# 7   NEM210409C00055500 2021-03-15 17:59:59    55.5       6.73   6.30   6.55
# 8   NEM210409C00056000 2021-04-01 15:28:09    56.0       5.15   5.90   6.00
# 9   NEM210409C00056500 2021-03-15 17:29:58    56.5       5.64   5.30   5.80
# 10  NEM210409C00057000 2021-03-31 16:10:12    57.0       3.62   4.90   5.00
# ...

# %%
yf.Ticker(ticker).options
# Out:
# ('2021-04-09',
#  '2021-04-16',
#  '2021-04-23',
#  '2021-04-30',
#  '2021-05-07',
#  '2021-05-14',
#  '2021-05-21',
#  '2021-06-18',
#  '2021-09-17',
#  '2022-01-21',
#  '2023-01-20')

# %%
yf.Ticker(ticker).quarterly_balance_sheet
# Out:
#                                     2020-12-31    2020-09-30    2020-06-30  \
# Capital Surplus                   1.810300e+10  1.815600e+10  1.813000e+10
# Total Liab                        1.749000e+10  1.693100e+10  1.691400e+10
# Total Stockholder Equity          2.300800e+10  2.266100e+10  2.200400e+10
# Minority Interest                 8.710000e+08  9.590000e+08  9.670000e+08
# Other Current Liab                1.358000e+09  9.170000e+08  6.590000e+08
# Total Assets                      4.136900e+10  4.055100e+10  3.988500e+10
# Common Stock                      1.287000e+09  1.292000e+09  1.291000e+09
# Other Current Assets              4.360000e+08  4.070000e+08  5.140000e+08
# Retained Earnings                 4.002000e+09  3.623000e+09  2.989000e+09
# Other Liab                        7.985000e+09  8.109000e+09  8.402000e+09
# Good Will                         2.771000e+09  2.771000e+09  2.771000e+09
# ...

# %%
yf.Ticker(ticker).quarterly_cashflow
# Out:
#                                              2020-12-31    2020-09-30  \
# Investments                               -4.700000e+07  3.500000e+07
# Change To Liabilities                      4.400000e+07 -4.000000e+07
# Total Cashflows From Investing Activities -4.110000e+08 -3.370000e+08
# Net Borrowings                            -1.700000e+07 -1.600000e+07
# Total Cash From Financing Activities      -5.610000e+08 -2.420000e+08
# Change To Operating Activities             3.680000e+08  2.200000e+08
# Issuance Of Stock                          1.000000e+06  5.000000e+07
# Net Income                                 8.240000e+08  8.390000e+08
# Change In Cash                             7.160000e+08  1.021000e+09
# Repurchase Of Stock                       -2.030000e+08 -6.000000e+06
# Effect Of Exchange Rate                    2.000000e+06  4.000000e+06
# Total Cash From Operating Activities       1.686000e+09  1.596000e+09
# ...

# %%
yf.Ticker(ticker).quarterly_earnings
# Out:
#             Revenue   Earnings
# Quarter
# 1Q2020   2581000000  822000000
# 2Q2020   2365000000  344000000
# 3Q2020   3170000000  839000000
# 4Q2020   3381000000  824000000

# %%
yf.Ticker(ticker).quarterly_financials
# Out:
#                                           2020-12-31    2020-09-30  \
# Research Development                      30000000.0    39000000.0
# Effect Of Accounting Charges                    None          None
# Income Before Tax                       1004000000.0   933000000.0
# Minority Interest                        871000000.0   959000000.0
# Net Income                               824000000.0   839000000.0
# Selling General Administrative            71000000.0   151000000.0
# Gross Profit                            1777000000.0  1869000000.0
# Ebit                                    1080000000.0  1043000000.0
# Operating Income                        1080000000.0  1043000000.0
# Other Operating Expenses                        None          None
# Interest Expense                         -73000000.0   -75000000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# ...

# %%
PERIOD_ATR = 14
PERIOD_Z = 30

PLOT = True

for ticker in tickers:
    try:
        data = web.get_data_yahoo(ticker, start, end)
        data = data.reset_index()
        
        data['Quintile'] = pd.qcut(data['Close'], 5, labels=False)
        ATR(data, PERIOD_ATR)
        data['Z'] = (data['ATR'] - data['ATR'].rolling(PERIOD_Z).mean()) / data['ATR'].rolling(PERIOD_Z).std()
        data['Logreturn'] = np.log(data['Adj Close']/data['Adj Close'].shift(1))
        data = data.dropna()
        #data = data.reset_index()
        
        if PLOT:
       
            plt.figure(figsize=(15,10))

            plt.subplot(3,1,1)
            plt.plot(data['Adj Close'])
            plt.title(ticker)
            plt.grid(True)
        
            plt.subplot(3,1,2)
            plt.plot(data['Quintile'], c='g')
            plt.grid(True)
        
            plt.subplot(3,1,3)
            plt.plot(data['Z'], c='r')
            plt.hlines(2, min(data.index), max(data.index), linestyles='dashdot')
            plt.hlines(-2, min(data.index),  max(data.index), linestyles='dashdot')
            plt.title(f'Z-score({PERIOD_Z}) from ATR({PERIOD_ATR})')
            plt.grid(True)

            plt.show()
        
        
    except:
        print(f'Cannot calculate for {ticker}!')
